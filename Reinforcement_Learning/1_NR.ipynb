# %%
import gymnasium as gym
import random

# %%
# Setup the environment

env = gym.make('CartPole-v0', render_mode='human')
states = env.observation_space.shape[0]
actions = env.action_space.n
# Out:
# c:\Users\ashut\anaconda3\envs\tensorflow_env\lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
env
# Out:
# <TimeLimit<OrderEnforcing<PassiveEnvChecker<CartPoleEnv<CartPole-v0>>>>>

# %%
env.observation_space
# Out:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
states
# Out:
# 4

# %%
actions
# Out:
# 2

# %%
# Build the Random Agent

from os import truncate


episodes = 10

for episode in range(1, episodes + 1):
    state = env.reset()
    done = False 
    score = 0
    
    while not done:
        env.render()
        action = random.choice([0, 1])
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score += reward
    print('Episode:{} Score{}'.format(episode, score))
    
env.close()
# Out:
# Episode:1 Score26.0
# Episode:2 Score11.0
# Episode:3 Score42.0
# Episode:4 Score16.0
# Episode:5 Score32.0
# Episode:6 Score15.0
# Episode:7 Score36.0
# Episode:8 Score31.0
# Episode:9 Score27.0
# Episode:10 Score22.0

# %%
# Deep Learning to improve performance

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 4
#       1 # Deep Learning to improve performance
#       3 import numpy as np
# ----> 4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Dense, Flatten
#       6 from tensorflow.keras.optimizers import Adam
#
# ModuleNotFoundError: No module named 'tensorflow.keras'
