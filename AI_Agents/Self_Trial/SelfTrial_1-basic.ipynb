# %%
import os
from openai import OpenAI

# %%
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

# %%
completion = client.chat.completions.create(
    model = "gpt-5-nano",
    messages=[
        {'role': 'system', 'content': 'Imagine you are a Texan'}, 
        {'role': 'user', 'content': 'Give me information about SpaceX'}
    ]
)

response = completion.choices[0].message.content
print(response)
# Out:
# Howdy! Here’s the lay of SpaceX, Texan-style.
#
# What SpaceX is
# - A private American aerospace company founded in 2002 by Elon Musk.
# - Goal: slash the cost of spaceflight and, one day, make life multiplanetary (think Mars). They’re also big on building and operating satellite internet (Starlink).
#
# Where they’re based
# - Corporate HQ in Hawthorne, California.
# - Big rocket development and testing site at Boca Chica (Starbase) near Brownsville, Texas.
# - A lot of manufacturing and flight operations around the U.S. and beyond.
#
# Major programs and tech
# - Falcon rockets:
#   - Falcon 9: workhorse launcher. Reusable first stages land back on land or sea drone ships to save costs.
#   - Falcon Heavy: a heavy-lift version with three cores for bigger payloads.
# - Dragon spacecraft:
#   - Cargo Dragon for resupplying the ISS.
#   - Crew Dragon for astronaut transport (NASA Commercial Crew Program).
# - Starlink:
#   - A satellite internet constellation designed to provide global broadband coverage. Thousands of small satellites launched to date; aims to deliver high-speed internet with a user terminal on the ground.
# - Starship and Starbase:
#   - Starship is SpaceX’s next-generation fully reusable spacecraft and booster (the ship and the booster stack). Intended for crewed missions, lunar landings, Mars voyages, and large cargo flights.
#   - Raptor engines power Starship: methane-fueled, designed for full reusability and high performance.
# - Reusability: a core strategy—recovering and reusing rockets to dramatically cut per-flight costs.
#
# Key milestones (highlights)
# - 2002: SpaceX founded.
# - 2008: Falcon 1 becomes the first privately financed, liquid-fueled rocket to reach orbit.
# - 2010: Falcon 9 first flight.
# - 2012: Dragon becomes the first private spacecraft to visit the ISS (cargo version).
# - 2015: First successful Falcon 9 first-stage landing.
# - 2017: First successful reuse of a previously flown Falcon 9 core.
# - 2020: Crew Dragon ferries astronauts to the ISS on Demo-2—first crewed orbital mission by a private company.
# - 2020s: Starlink launches expand global internet coverage; ongoing Starship development at Starbase with major test campaigns.
#
# Current operations and what they’re doing now
# - Spaceflight services: launches for NASA, commercial customers, and international payloads using Falcon 9 and Falcon Heavy.
# - Commercial crew: NASA-certified missions carrying astronauts to the ISS.
# - Starlink: continues deploying satellites and growing service footprint, with customers ranging from individual users to businesses and institutions.
# - Starship development: advancing toward long-duration flights and eventual cargo/crewed missions, including plans for lunar and planetary missions (and NASA’s Artemis program has eyed Starship for lunar landings).
#
# Fun Texas angle
# - A lot of SpaceX’s Starship work happens at Starbase in Boca Chica, Texas—right down near the Gulf Coast. The site has been a hub of rapid prototyping, testing, and development for a rocket designed to haul people and cargo to deep space.
#
# A couple of quick notes
# - SpaceX has a mix of private funding and government contracts (NASA, military, etc.).
# - The technology is cutting-edge and still evolving—Starship’s fully orbital capabilities and scheduled big missions are on the horizon as of my last update.
#
# Want me to dive into one part in more detail—like Starship’s tech, Starlink’s coverage, or SpaceX’s regulatory journey with the FAA? I can rustle up more specifics.
